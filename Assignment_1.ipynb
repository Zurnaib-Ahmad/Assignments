# %% [markdown]
# # 1. Student Information

# %%
name = "Ghulam-e-Mustafa"
age = 21
city = "Karachi"
student_status = "Single"

# %%
print(f"Student Name : {name}", f"Student Age : {age}", f"City : {city}", f"Student Status : {student_status}" ,sep = "\n")
# Out:
# Student Name : Ghulam-e-Mustafa
# Student Age : 21
# City : Karachi
# Student Status : Single

# %% [markdown]
# # 2. Data Types

# %%
haroon = "Haroon is a good student"
haroon_age = 20
haroon_inter_percentage = 77.34
barve_haroon = False

# %%
print(haroon, type(haroon)) 
print(haroon_age, type(haroon_age)) 
print(haroon_inter_percentage, type(haroon_inter_percentage)) 
print(barve_haroon, type(barve_haroon))
# Out:
# Haroon is a good student <class 'str'>
# 20 <class 'int'>
# 77.34 <class 'float'>
# False <class 'bool'>

# %% [markdown]
# # 3. Arithmetic Operaters

# %%
four = 4
six = 6

# %% [markdown]
# ####  Addition

# %%
print(four + six)
# Out:
# 10

# %% [markdown]
# #### Substraction

# %%
print(six - four)
# Out:
# 2

# %% [markdown]
# #### Multipication

# %%
print(six * four)
# Out:
# 24

# %% [markdown]
# #### Division

# %%
print(four / six)
# Out:
# 0.6666666666666666

# %%
print(four // six)
# Out:
# 0

# %% [markdown]
# #### Modulus

# %%
print(four % six)
# Out:
# 4

# %% [markdown]
# #### Power

# %%
print(four ** six)
# Out:
# 4096

# %% [markdown]
# # 4. Student Marks Calculator

# %%
physics = 70
math = 88
chemistry = 66
total_marks = physics + math + chemistry

# %%
print(f"Total Marks : {total_marks}", f"Average Marks : {total_marks//3}", sep = "\n")
# Out:
# Total Marks : 224
# Average Marks : 74

# %% [markdown]
# # 5. Shopping Bill

# %%
laptop_model = "HP 250 G10 Ci3 N305 (8GB-512GB SSD)"
laptop_price =  179999
laptop_quantity = 3
total_bill = laptop_price * laptop_quantity

# %%
print(f"Laptop Model : {laptop_model}", f"Price : {laptop_price}", f"Quantity : {laptop_quantity}", f"Total Bill : {total_bill}", sep = "\n")
# Out:
# Laptop Model : HP 250 G10 Ci3 N305 (8GB-512GB SSD)
# Price : 179999
# Quantity : 3
# Total Bill : 539997

# %% [markdown]
# # 6. Rectangle Area

# %%
length = 3
width = 6
area = length * width

# %%
print(f"Area of Rectangle = {area} cm2.", f"Perimeter of Rectangle = {2 *area} cm2.", sep = "\n")
# Out:
# Area of Rectangle = 18 cm2.
# Perimeter of Rectangle = 36 cm2.

# %% [markdown]
# # 7. Time Converter

# %%
minutes = 250

# %%
print(f"Number Of Hours : {minutes // 60} hours.", f"Remaining Minutes : {minutes % 60} minutes.", sep = "\n")
# Out:
# Number Of Hours : 4 hours.
# Remaining Minutes : 10 minutes.

# %% [markdown]
# # 8. Student Eligibility

# %%
marks = 80
attendence = 80

# %%
print(f"Is Student Ele=igible? : {(marks >= 50 and attendence >= 75)}.")
# Out:
# Is Student Ele=igible? : True.

# %% [markdown]
# # 9. Logical Operators

# %%
a = True
b = False

# %%
print(f"• a and b = {a and b}", f"• a or b = {a or b}", f"• not a = {not a}", f"• not b = {not b}", sep = "\n")
# Out:
# • a and b = False
# • a or b = True
# • not a = False
# • not b = True

# %% [markdown]
# # Final Challenge Student Report

# %%
student_name = input("Enter your name : ")
student_age = int(input("Enter your age : "))
marks_of_physics = int(input("Enter your Physics numbers : "))
marks_of_math = int(input("Enter your Math numbers : "))
marks_of_chemistry = int(input("Enter your Chemistry numbers : "))
student_class_attendence = int(input("Enter your Class Attendence : "))
marks_of_3_subjects = marks_of_physics + marks_of_math + marks_of_chemistry
# Out:
# Enter your name :  Ghulam Mustafa
# Enter your age :  19
# Enter your Physics numbers :  80
# Enter your Math numbers :  89
# Enter your Chemistry numbers :  67
# Enter your Class Attendence :  79

# %%
print(f"1. Student Name : {student_name}", f"   Student Age : {student_age}", f"   Class Attendence : {student_class_attendence}", sep = "\n")
# Out:
# 1. Student Name : Ghulam Mustafa
#    Student Age : 19
#    Class Attendence : 79

# %%
print(f"2. Total Marks : {marks_of_3_subjects}", sep = "\n")
# Out:
# 2. Total Marks : 236

# %%
student_average_marks = marks_of_3_subjects // 3
print(f"3. Total Marks : {student_average_marks}", sep = "\n")
# Out:
# 3. Total Marks : 78

# %%
print(f"4. Student is Eligible : {(student_average_marks >= 50) and (student_class_attendence >= 75)}", sep = "\n")
# Out:
# 4. Student is Eligible : True
